# %% [markdown]
# <a href="https://colab.research.google.com/github/sujithcplusplus/Huggingface-audio-transformers/blob/main/Audio_classification_for_music.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qq transformers datasets accelerate evaluate -U
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 11.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.0 MB/s eta 0:00:00

# %%
from datasets import load_dataset

gtzan = load_dataset("marsyas/gtzan", "all")
gtzan
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'audio', 'genre'],
#         num_rows: 999
#     })
# })

# %%
gtzan = gtzan["train"].train_test_split(seed=42, shuffle=True, test_size=0.1)
gtzan
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'audio', 'genre'],
#         num_rows: 899
#     })
#     test: Dataset({
#         features: ['file', 'audio', 'genre'],
#         num_rows: 100
#     })
# })

# %%
from transformers import AutoFeatureExtractor

model_id = "ntu-spml/distilhubert"
feature_extractor = AutoFeatureExtractor.from_pretrained(
    model_id, do_normalize=True, return_attention_mask=True
)
# Out:
# preprocessor_config.json:   0%|          | 0.00/214 [00:00<?, ?B/s]

# %%
max_duration = 30.0

def preprocess_function(examples):
    audio_arrays = [x["array"] for x in examples["audio"]]
    inputs = feature_extractor(
        audio_arrays,
        sampling_rate=feature_extractor.sampling_rate,
        max_length=int(feature_extractor.sampling_rate * max_duration),
        truncation=True,
        return_attention_mask=True,
    )
    return inputs

# %%
gtzan_encoded = gtzan.map(
    preprocess_function, remove_columns=["audio", "file"], batched=True, batch_size=200
)
gtzan_encoded
# Out:
# ...
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['genre', 'input_values', 'attention_mask'],
#         num_rows: 899
#     })
#     test: Dataset({
#         features: ['genre', 'input_values', 'attention_mask'],
#         num_rows: 100
#     })
# })

# %%
gtzan_encoded = gtzan_encoded.rename_column("genre", "label")
gtzan_encoded
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_values', 'attention_mask'],
#         num_rows: 899
#     })
#     test: Dataset({
#         features: ['label', 'input_values', 'attention_mask'],
#         num_rows: 100
#     })
# })

# %%
id2label_fn = gtzan["train"].features["genre"].int2str
id2label = {
    str(i): id2label_fn(i)
    for i in range(len(gtzan_encoded["train"].features["label"].names))
}
label2id = {v: k for k, v in id2label.items()}

# %%
from transformers import AutoModelForAudioClassification

num_labels = len(id2label)

model = AutoModelForAudioClassification.from_pretrained(
    model_id,
    num_labels=num_labels,
    label2id=label2id,
    id2label=id2label,
)
# Out:
# config.json:   0%|          | 0.00/1.30k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/94.0M [00:00<?, ?B/s]
# Some weights of HubertForSequenceClassification were not initialized from the model checkpoint at ntu-spml/distilhubert and are newly initialized: ['classifier.weight', 'encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'projector.weight', 'classifier.bias', 'encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'projector.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from transformers import TrainingArguments

model_name = model_id.split("/")[-1]
batch_size = 8
gradient_accumulation_steps = 1
num_train_epochs = 12

training_args = TrainingArguments(
    f"{model_name}-finetuned-gtzan",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=3e-5,
    gradient_accumulation_steps=gradient_accumulation_steps,
    auto_find_batch_size=True,
    num_train_epochs=num_train_epochs,
    warmup_ratio=0.1,
    logging_steps=5,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
    fp16=True,
    seed=42,
    push_to_hub=True
)

# %%
import evaluate
import numpy as np
metric = evaluate.load("accuracy")


def compute_metrics(eval_pred):
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)

# %%
from transformers import Trainer

trainer = Trainer(
    model,
    training_args,
    train_dataset=gtzan_encoded["train"],
    eval_dataset=gtzan_encoded["test"],
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='1356' max='1356' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1356/1356 1:56:04, Epoch 12/12]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.145700</td>
#       <td>2.072891</td>
#       <td>0.510000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.567500</td>
#       <td>1.515801</td>
#       <td>0.590000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.249800</td>
#       <td>1.224236</td>
#       <td>0.670000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.152600</td>
#       <td>1.022297</td>
#       <td>0.720000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.848900</td>
#       <td>0.847213</td>
# ...

# %%
kwargs = {
    "dataset_tags": "marsyas/gtzan",
    "dataset": "GTZAN",
    "model_name": f"{model_name}-finetuned-gtzan",
    "finetuned_from": model_id,
    "tasks": "audio-classification",
}

trainer.push_to_hub(**kwargs)
# Out:
# 'https://huggingface.co/kollis/distilhubert-finetuned-gtzan/tree/main/'
